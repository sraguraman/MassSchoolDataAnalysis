# %%
import pandas as pd
import numpy as np

# %%
school_data = pd.read_csv("school_data.csv")
print("completed reading data!")
print(school_data)
# Out:
# completed reading data!
#       School Code                                        School Name  \
# 0           10505                                      Abington High
# 1           10003                     Beaver Brook Elementary School
# 2           10002                           Center Elementary School
# 3           10405                               Frolio Middle School
# 4           10015                        Woodsdale Elementary School
# 5           30025                         Acushnet Elementary School
# 6           30305                        Albert F Ford Middle School
# 7           50003                      Agawam Early Childhood Center
# 8           50505                                        Agawam High
# 9           50405                                 Agawam Junior High
# 10          50020                                  Benjamin J Phelps
# 11          50010                                 Clifford M Granger
# ...
